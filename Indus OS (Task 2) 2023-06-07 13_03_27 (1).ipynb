# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import count, mean, stddev,avg
spark = SparkSession.builder.appName("AppSummaryStatistics").getOrCreate()
df = spark.read.csv("dbfs:/FileStore/tables/export.csv", header=True, inferSchema=True)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>App Name</th><th>Size (bytes)</th><th>App id</th><th>Currency</th><th>Price</th><th>Rating (All)</th><th>Rating (Current)</th><th>Avg Rating (All)</th><th>Avy Rating (Current)</th><th>Version</th><th>Rating(Content)</th><th>Prefrence</th><th>Supp Devices</th><th>Screenshot</th><th>Supp Lang</th><th>Vpp Lic</th></tr></thead><tbody><tr><td>PAC-MAN Premium</td><td>100788224</td><td>281656475</td><td>USD</td><td>3.99</td><td>21292</td><td>26</td><td>4.0</td><td>4.5</td><td>6.3.5</td><td>4+</td><td>Games</td><td>38</td><td>5</td><td>10</td><td>1</td></tr><tr><td>Evernote - stay organized</td><td>158578688</td><td>281796108</td><td>USD</td><td>0.0</td><td>161065</td><td>26</td><td>4.0</td><td>3.5</td><td>8.2.2</td><td>4+</td><td>Productivity</td><td>37</td><td>5</td><td>23</td><td>1</td></tr><tr><td>WeatherBug - Local Weather, Radar, Maps, Alerts</td><td>100524032</td><td>281940292</td><td>USD</td><td>0.0</td><td>188583</td><td>2822</td><td>3.5</td><td>4.5</td><td>5.0.0</td><td>4+</td><td>Weather</td><td>37</td><td>5</td><td>3</td><td>1</td></tr><tr><td>eBay: Best App to Buy, Sell, Save! Online Shopping</td><td>128512000</td><td>282614216</td><td>USD</td><td>0.0</td><td>262241</td><td>649</td><td>4.0</td><td>4.5</td><td>5.10.0</td><td>12+</td><td>Shopping</td><td>37</td><td>5</td><td>9</td><td>1</td></tr><tr><td>Bible</td><td>92774400</td><td>282935706</td><td>USD</td><td>0.0</td><td>985920</td><td>5320</td><td>4.5</td><td>5.0</td><td>7.5.1</td><td>4+</td><td>Reference</td><td>37</td><td>5</td><td>45</td><td>1</td></tr><tr><td>Shanghai Mahjong</td><td>10485713</td><td>283619399</td><td>USD</td><td>0.99</td><td>8253</td><td>5516</td><td>4.0</td><td>4.0</td><td>1.8</td><td>4+</td><td>Games</td><td>47</td><td>5</td><td>1</td><td>1</td></tr><tr><td>PayPal - Send and request money safely</td><td>227795968</td><td>283646709</td><td>USD</td><td>0.0</td><td>119487</td><td>879</td><td>4.0</td><td>4.5</td><td>6.12.0</td><td>4+</td><td>Finance</td><td>37</td><td>0</td><td>19</td><td>1</td></tr><tr><td>Pandora - Music & Radio</td><td>130242560</td><td>284035177</td><td>USD</td><td>0.0</td><td>1126879</td><td>3594</td><td>4.0</td><td>4.5</td><td>8.4.1</td><td>12+</td><td>Music</td><td>37</td><td>4</td><td>1</td><td>1</td></tr><tr><td>PCalc - The Best Calculator</td><td>49250304</td><td>284666222</td><td>USD</td><td>9.99</td><td>1117</td><td>4</td><td>4.5</td><td>5.0</td><td>3.6.6</td><td>4+</td><td>Utilities</td><td>37</td><td>5</td><td>1</td><td>1</td></tr><tr><td>Ms. PAC-MAN</td><td>70023168</td><td>284736660</td><td>USD</td><td>3.99</td><td>7885</td><td>40</td><td>4.0</td><td>4.0</td><td>4.0.4</td><td>4+</td><td>Games</td><td>38</td><td>0</td><td>10</td><td>1</td></tr><tr><td>Solitaire by MobilityWare</td><td>49618944</td><td>284791396</td><td>USD</td><td>4.99</td><td>76720</td><td>4017</td><td>4.5</td><td>4.5</td><td>4.10.1</td><td>4+</td><td>Games</td><td>38</td><td>4</td><td>11</td><td>1</td></tr><tr><td>SCRABBLE Premium</td><td>227547136</td><td>284815117</td><td>USD</td><td>7.99</td><td>105776</td><td>166</td><td>3.5</td><td>2.5</td><td>5.19.0</td><td>4+</td><td>Games</td><td>37</td><td>0</td><td>6</td><td>1</td></tr><tr><td>Google – Search made just for mobile</td><td>179979264</td><td>284815942</td><td>USD</td><td>0.0</td><td>479440</td><td>203</td><td>3.5</td><td>4.0</td><td>27</td><td>17+</td><td>Utilities</td><td>37</td><td>4</td><td>33</td><td>1</td></tr><tr><td>Bank of America - Mobile Banking</td><td>160925696</td><td>284847138</td><td>USD</td><td>0.0</td><td>119773</td><td>2336</td><td>3.5</td><td>4.5</td><td>7.3.8</td><td>4+</td><td>Finance</td><td>37</td><td>0</td><td>2</td><td>1</td></tr><tr><td>FreeCell</td><td>55153664</td><td>284862767</td><td>USD</td><td>4.99</td><td>6340</td><td>668</td><td>4.5</td><td>4.5</td><td>4.0.3</td><td>4+</td><td>Games</td><td>38</td><td>5</td><td>2</td><td>1</td></tr><tr><td>Tr ...

# %%
summary_df = df.groupBy("Avg Rating (All)").agg(
    count("Rating (All)").alias("num_Rating (All)"),
    
    stddev("Rating (All)").alias("std_dev_Ratings (All)"),
)


display(summary_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Avg Rating (All)</th><th>num_Rating (All)</th><th>std_dev_Ratings (All)</th></tr></thead><tbody><tr><td>0.0</td><td>929</td><td>0.0</td></tr><tr><td>3.5</td><td>702</td><td>121402.43867549911</td></tr><tr><td>4.5</td><td>2663</td><td>98461.50384751921</td></tr><tr><td>2.5</td><td>196</td><td>31599.534571559234</td></tr><tr><td>1.0</td><td>44</td><td>67.30644867935493</td></tr><tr><td>4.0</td><td>1626</td><td>40663.286575614555</td></tr><tr><td>3.0</td><td>383</td><td>38282.764039463436</td></tr><tr><td>2.0</td><td>106</td><td>18942.88526700945</td></tr><tr><td>1.5</td><td>56</td><td>389.0611543423242</td></tr><tr><td>5.0</td><td>492</td><td>49216.28909050784</td></tr></tbody></table></div>

# %%
from pyspark.sql import SparkSession
import pandas as pd
import matplotlib.pyplot as plt

# %%
spark = SparkSession.builder.appName("DataVisualization").getOrCreate()

# %%
df = spark.read.format("csv").option("header", "true").load("dbfs:/FileStore/tables/export.csv")
pandas_df = df.toPandas()

# %%
plt.hist(pandas_df['Rating (All)'], bins=10, color='skyblue')
plt.xlabel('Rating (All)')
plt.ylabel('Price')
plt.title('price Distribution')
plt.show()

# %%
plt.scatter(pandas_df['Size (bytes)'], pandas_df['Rating (All)'], color='orange')
plt.xlabel('Size (bytes)')
plt.ylabel('Rating (All)')
plt.title('Size (bytes) vs Rating (All)')
plt.show()

# %%
device_counts = pandas_df['Supp Devices'].value_counts()
device_counts.plot(kind='bar', color='green')
plt.xlabel('Supp Devices')
plt.ylabel('Count')
plt.title('Supported Devices Distribution')
plt.show()

# %%
language_counts = pandas_df['Supp Lang'].value_counts()
language_counts.plot(kind='bar', color='purple')
plt.xlabel('Supp Lang')
plt.ylabel('Count')
plt.title('Languages Distribution')
plt.show()
